# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_data=pd.read_csv(r"C:\Users\Elif\Desktop\violence_data.csv")
raw_data.head()
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RecordID               12600 non-null  int64
#  1   Country                12600 non-null  object
#  2   Gender                 12600 non-null  object
#  3   Demographics Question  12600 non-null  object
#  4   Demographics Response  12600 non-null  object
#  5   Question               12600 non-null  object
#  6   Survey Year            12600 non-null  object
#  7   Value                  11187 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 787.6+ KB

# %%
raw_data.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Armenia', 'Azerbaijan',
#        'Bangladesh', 'Benin', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Chad', 'Colombia', 'Comoros', 'Congo',
#        'Congo Democratic Republic', "Cote d'Ivoire", 'Dominican Republic',
#        'Egypt', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia',
#        'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Jordan', 'Kenya', 'Kyrgyz Republic',
#        'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Maldives', 'Mali',
#        'Moldova', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Peru', 'Philippines',
#        'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'South Africa', 'Tajikistan', 'Tanzania', 'Timor-Leste', 'Togo',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
raw_data.Question.unique()
# Out:
# array(['... if she burns the food',
#        '... for at least one specific reason',
#        '... if she argues with him',
#        '... if she goes out without telling him',
#        '... if she neglects the children',
#        '... if she refuses to have sex with him'], dtype=object)

# %%
cts=raw_data[(raw_data.Country == 'Afghanistan') | (raw_data.Country == 'Albania') | (raw_data.Country == 'Turkey') | 
            (raw_data.Country == 'Colombia') | (raw_data.Country == 'Pakistan') | (raw_data.Country == 'Moldova') |
            (raw_data.Country == 'Ukraine') | (raw_data.Country == 'Azerbaijan') ]

cts
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12055       207      Ukraine      M             Residence
# 12056       277      Ukraine      M             Residence
# 12057       277      Ukraine      M             Residence
# 12058       347      Ukraine      M             Residence
# 12059       347      Ukraine      M             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# ...                             ...                                      ...
# 12055                         Urban  ... if she goes out without telling him
# 12056                         Rural         ... if she neglects the children
# 12057                         Urban         ... if she neglects the children
# 12058                         Rural  ... if she refuses to have sex with him
# 12059                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 0      01/01/2015    NaN
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 4      01/01/2015   13.8
# ...           ...    ...
# 12055  01/01/2007    3.9
# 12056  01/01/2007   10.5
# 12057  01/01/2007    8.4
# 12058  01/01/2007    2.7
# 12059  01/01/2007    1.5
#
# [1440 rows x 8 columns]

# %%
cts_df=cts.drop(columns=['RecordID','Survey Year'])
cts_df
# Out:
#            Country Gender Demographics Question         Demographics Response  \
# 0      Afghanistan      F        Marital status                 Never married
# 1      Afghanistan      F             Education                        Higher
# 2      Afghanistan      F             Education                     Secondary
# 3      Afghanistan      F             Education                       Primary
# 4      Afghanistan      F        Marital status  Widowed, divorced, separated
# ...            ...    ...                   ...                           ...
# 12055      Ukraine      M             Residence                         Urban
# 12056      Ukraine      M             Residence                         Rural
# 12057      Ukraine      M             Residence                         Urban
# 12058      Ukraine      M             Residence                         Rural
# 12059      Ukraine      M             Residence                         Urban
#
#                                       Question  Value
# 0                    ... if she burns the food    NaN
# 1                    ... if she burns the food   10.1
# 2                    ... if she burns the food   13.7
# 3                    ... if she burns the food   13.8
# 4                    ... if she burns the food   13.8
# ...                                        ...    ...
# 12055  ... if she goes out without telling him    3.9
# 12056         ... if she neglects the children   10.5
# 12057         ... if she neglects the children    8.4
# 12058  ... if she refuses to have sex with him    2.7
# 12059  ... if she refuses to have sex with him    1.5
#
# [1440 rows x 6 columns]

# %%
cts_df.dropna()
# Out:
#            Country Gender Demographics Question         Demographics Response  \
# 1      Afghanistan      F             Education                        Higher
# 2      Afghanistan      F             Education                     Secondary
# 3      Afghanistan      F             Education                       Primary
# 4      Afghanistan      F        Marital status  Widowed, divorced, separated
# 5      Afghanistan      F            Employment             Employed for kind
# ...            ...    ...                   ...                           ...
# 12055      Ukraine      M             Residence                         Urban
# 12056      Ukraine      M             Residence                         Rural
# 12057      Ukraine      M             Residence                         Urban
# 12058      Ukraine      M             Residence                         Rural
# 12059      Ukraine      M             Residence                         Urban
#
#                                       Question  Value
# 1                    ... if she burns the food   10.1
# 2                    ... if she burns the food   13.7
# 3                    ... if she burns the food   13.8
# 4                    ... if she burns the food   13.8
# 5                    ... if she burns the food   17.0
# ...                                        ...    ...
# 12055  ... if she goes out without telling him    3.9
# 12056         ... if she neglects the children   10.5
# 12057         ... if she neglects the children    8.4
# 12058  ... if she refuses to have sex with him    2.7
# 12059  ... if she refuses to have sex with him    1.5
#
# [1260 rows x 6 columns]

# %%
cts_survey_df=cts_df.pivot_table(index=['Country','Gender','Demographics Question','Demographics Response'],
                                columns=['Question'],values=['Value'])
cts_survey_df
# Out:
#                                                                                                      Value  \
# Question                                                              ... for at least one specific reason
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                                        80.1
#                                          25-34                                                        81.5
#                                          35-49                                                        79.0
#                    Education             Higher                                                       61.1
#                                          No education                                                 81.0
# ...                                                                                                    ...
# Ukraine     M      Marital status        Married or living together                                    8.9
#                                          Never married                                                11.5
#                                          Widowed, divorced, separated                                 22.0
#                    Residence             Rural                                                        13.9
#                                          Urban                                                        10.0
#
#                                                                                                   \
# Question                                                              ... if she argues with him
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                              57.5
#                                          25-34                                              60.0
#                                          35-49                                              59.8
#                    Education             Higher                                             37.7
#                                          No education                                       60.2
# ...                                                                                          ...
# Ukraine     M      Marital status        Married or living together                          3.2
#                                          Never married                                       6.1
#                                          Widowed, divorced, separated                       13.0
#                    Residence             Rural                                               6.8
#                                          Urban                                               4.6
#
#                                                                                                  \
# Question                                                              ... if she burns the food
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                             17.3
#                                          25-34                                             18.2
#                                          35-49                                             18.8
#                    Education             Higher                                            10.1
#                                          No education                                      19.1
# ...                                                                                         ...
# Ukraine     M      Marital status        Married or living together                         0.4
#                                          Never married                                      1.1
#                                          Widowed, divorced, separated                       1.2
#                    Residence             Rural                                              0.9
#                                          Urban                                              0.6
#
#                                                                                                                \
# Question                                                              ... if she goes out without telling him
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                                           67.7
#                                          25-34                                                           68.5
#                                          35-49                                                           64.7
#                    Education             Higher                                                          41.1
#                                          No education                                                    68.4
# ...                                                                                                       ...
# Ukraine     M      Marital status        Married or living together                                       2.8
#                                          Never married                                                    4.3
#                                          Widowed, divorced, separated                                    11.5
#                    Residence             Rural                                                            5.0
#                                          Urban                                                            3.9
#
#                                                                                                         \
# Question                                                              ... if she neglects the children
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                                    46.5
#                                          25-34                                                    50.2
#                                          35-49                                                    48.1
#                    Education             Higher                                                   33.4
#                                          No education                                             48.9
# ...                                                                                                ...
# Ukraine     M      Marital status        Married or living together                                7.0
#                                          Never married                                             9.3
#                                          Widowed, divorced, separated                             19.0
#                    Residence             Rural                                                    10.5
#                                          Urban                                                     8.4
#
#
# Question                                                              ... if she refuses to have sex with him
# Country     Gender Demographics Question Demographics Response
# Afghanistan F      Age                   15-24                                                           32.1
#                                          25-34                                                           34.3
#                                          35-49                                                           33.5
#                    Education             Higher                                                          10.8
#                                          No education                                                    34.2
# ...                                                                                                       ...
# Ukraine     M      Marital status        Married or living together                                       1.4
#                                          Never married                                                    2.1
#                                          Widowed, divorced, separated                                     3.4
#                    Residence             Rural                                                            2.7
#                                          Urban                                                            1.5
#
# [210 rows x 6 columns]

# %%
ctssurvey_df=cts_survey_df.T.reset_index(drop=True).T.reset_index()

# %%
#Rename columns
ctssurvey_df.columns=['Country',
                      'Gender',
                      'Demographics_question',
                      'Demographics_response',
                      'Violence_any_reason',
                      'Violence_argue',
                      'Violence_food',
                      'Violence_goingout',
                      'Violence_neglect',
                      'Violence_sex'
    
]

# %%
ctssurvey_df
# Out:
#          Country Gender Demographics_question         Demographics_response  \
# 0    Afghanistan      F                   Age                         15-24
# 1    Afghanistan      F                   Age                         25-34
# 2    Afghanistan      F                   Age                         35-49
# 3    Afghanistan      F             Education                        Higher
# 4    Afghanistan      F             Education                  No education
# ..           ...    ...                   ...                           ...
# 205      Ukraine      M        Marital status    Married or living together
# 206      Ukraine      M        Marital status                 Never married
# 207      Ukraine      M        Marital status  Widowed, divorced, separated
# 208      Ukraine      M             Residence                         Rural
# 209      Ukraine      M             Residence                         Urban
#
#      Violence_any_reason  Violence_argue  Violence_food  Violence_goingout  \
# 0                   80.1            57.5           17.3               67.7
# 1                   81.5            60.0           18.2               68.5
# 2                   79.0            59.8           18.8               64.7
# 3                   61.1            37.7           10.1               41.1
# 4                   81.0            60.2           19.1               68.4
# ..                   ...             ...            ...                ...
# 205                  8.9             3.2            0.4                2.8
# 206                 11.5             6.1            1.1                4.3
# 207                 22.0            13.0            1.2               11.5
# 208                 13.9             6.8            0.9                5.0
# 209                 10.0             4.6            0.6                3.9
#
#      Violence_neglect  Violence_sex
# 0                46.5          32.1
# 1                50.2          34.3
# 2                48.1          33.5
# 3                33.4          10.8
# 4                48.9          34.2
# ..                ...           ...
# 205               7.0           1.4
# 206               9.3           2.1
# 207              19.0           3.4
# 208              10.5           2.7
# 209               8.4           1.5
#
# [210 rows x 10 columns]

# %%
new_df=ctssurvey_df.drop(columns=['Violence_any_reason','Violence_argue','Violence_food', 'Violence_goingout',
                                  'Violence_neglect','Violence_sex'])

# %%
new_df
# Out:
#          Country Gender Demographics_question         Demographics_response
# 0    Afghanistan      F                   Age                         15-24
# 1    Afghanistan      F                   Age                         25-34
# 2    Afghanistan      F                   Age                         35-49
# 3    Afghanistan      F             Education                        Higher
# 4    Afghanistan      F             Education                  No education
# ..           ...    ...                   ...                           ...
# 205      Ukraine      M        Marital status    Married or living together
# 206      Ukraine      M        Marital status                 Never married
# 207      Ukraine      M        Marital status  Widowed, divorced, separated
# 208      Ukraine      M             Residence                         Rural
# 209      Ukraine      M             Residence                         Urban
#
# [210 rows x 4 columns]

# %%
new_df.dropna()
# Out:
#          Country Gender Demographics_question         Demographics_response
# 0    Afghanistan      F                   Age                         15-24
# 1    Afghanistan      F                   Age                         25-34
# 2    Afghanistan      F                   Age                         35-49
# 3    Afghanistan      F             Education                        Higher
# 4    Afghanistan      F             Education                  No education
# ..           ...    ...                   ...                           ...
# 205      Ukraine      M        Marital status    Married or living together
# 206      Ukraine      M        Marital status                 Never married
# 207      Ukraine      M        Marital status  Widowed, divorced, separated
# 208      Ukraine      M             Residence                         Rural
# 209      Ukraine      M             Residence                         Urban
#
# [210 rows x 4 columns]

# %%
ctssurvey_df.to_excel('eightCountries.xlsx')
